# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
import numpy as np
import tensorflow.keras as keras
from tensorflow.keras import models, layers

# %%
import pandas as pd
import os

# %%
def medication_data(income_path):
    csv_path = os.path.join(income_path,"mu.csv")
    return pd.read_csv(csv_path,sep=',',engine='python')

# %%
result = medication_data(".")

# %%
len(result)
# Out:
# 479230

# %%
result.head()
# Out:
#    order  patient_number  presc_date presc_dept  order_date presc_code  \
# 0      0        10505120  2016-08-18         DM  2016-08-18       L209
# 1      1        10505120  2016-08-18         DM  2016-08-18       L209
# 2      2        10505120  2016-08-18         DM  2016-08-18       L209
# 3      3        10105557  2016-01-26         OS  2016-01-26       T143
# 4      4        10064596  2016-01-21         OS  2016-01-21       G629
#
#                                    presc_information  order_code  \
# 0                     Atopic dermatitis, unspecified     VAS10-O
# 1                     Atopic dermatitis, unspecified   PIMEC-CR1
# 2                     Atopic dermatitis, unspecified      PDV-CR
# 3  Dislocation, sprain and strain of unspecified ...  NAPRO5SOM2
# 4                        Polyneuropathy, unspecified       LAYLA
#
#                              order_name  sum_medic_count  medic_duration
# 0                         Vaseline 10g*                2               1
# 1                  Elidel Cream 1% 10g*                2               1
# 2  Prednisolone Valeroacetate  1.3% 20g                2               1
# 3                   Vimovo tab 500/20mg                2              15
# 4                             Layla tab                2              30

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479230 entries, 0 to 479229
# Data columns (total 11 columns):
# order                479230 non-null int64
# patient_number       479230 non-null int64
# presc_date           479230 non-null object
# presc_dept           479230 non-null object
# order_date           479230 non-null object
# presc_code           479230 non-null object
# presc_information    479230 non-null object
# order_code           479230 non-null object
# order_name           478743 non-null object
# sum_medic_count      479230 non-null int64
# medic_duration       479230 non-null int64
# dtypes: int64(4), object(7)
# memory usage: 40.2+ MB

# %%
result['patient_number'].value_counts()
# Out:
# 10271364    834
# 10016177    709
# 10595340    684
# 10669901    659
# 10315998    612
#            ...
# 10652216      1
# 10651525      1
# 10481386      1
# 10409677      1
# 10046097      1
# Name: patient_number, Length: 37014, dtype: int64

# %%
result.describe()
# Out:
#                order  patient_number  sum_medic_count  medic_duration
# count  479230.000000    4.792300e+05    479230.000000   479230.000000
# mean   239614.500000    1.044013e+07         1.829710       14.948079
# std    138341.929089    2.235415e+05         1.063725       26.829278
# min         0.000000    1.000010e+07         1.000000        1.000000
# 25%    119807.250000    1.024311e+07         1.000000        1.000000
# 50%    239614.500000    1.052012e+07         2.000000        4.000000
# 75%    359421.750000    1.064061e+07         2.000000       14.000000
# max    479229.000000    1.071575e+07        24.000000      365.000000

# %%
import matplotlib.pyplot as plt

# %% [raw]
# result.hist(bins=5, figsize=(20,15))

# %%
plt.show()

# %%
LABEL_COLUMN ='sum_medic_count'

# %%
LABELS = [0,1]

# %%
def get_dataset(file_path, **kwargs):
    dataset = tf.data.experimental.make_csv_dataset(file_path,
                                                    batch_size=32, # Artificially small to make examples easier to show.
                                                    label_name=LABEL_COLUMN,
                                                    na_value="?",
                                                    num_epochs=1,
                                                    num_parallel_reads=1,
                                                    ignore_errors=True,
                            
                                                    **kwargs)
    return dataset

# %%
PATH = './mu.csv'

# %%
raw_train_data = get_dataset(PATH)

# %%
def show_batch(dataset):
    for batch, label in dataset.take(1):
        for key, value in batch.items():
            print("{:20s}:{}".format(key,value.numpy()))
        print("label:",label.numpy())

# %%
show_batch(raw_train_data)
# Out:
# order               :[9336 5887  842 4197 8051 7520 8677 7714 1523 6539 8719 1035  154 2261
#  8193 1362 9262 3847 6086 7027 2372 8584   22 8488 6870 6786 7123 9135
#  2195 8382 4355 4028]
# patient_number      :[10624851 10577163 10124887 10195824 10142566 10497931 10001574 10163191
#  10511990 10549142 10599467 10005676 10206758 10234893 10251255 10561527
#  10169696 10560814 10629008 10035410 10311450 10597183 10276378 10620148
#  10072802 10128299 10068451 10462087 10096720 10481158 10598858 10148196]
# presc_date          :[b'2016-01-25' b'2016-01-11' b'2016-01-27' b'2016-01-22' b'2016-01-25'
#  b'2016-03-31' b'2016-03-23' b'2016-06-10' b'2016-02-03' b'2016-02-15'
#  b'2016-01-15' b'2016-04-11' b'2016-02-01' b'2016-01-29' b'2016-02-15'
#  b'2016-04-27' b'2016-03-17' b'2016-02-23' b'2016-01-04' b'2016-03-23'
#  b'2016-03-21' b'2016-01-12' b'2016-01-19' b'2016-01-19' b'2016-02-05'
#  b'2016-03-16' b'2016-01-14' b'2016-04-28' b'2016-02-04' b'2016-03-16'
#  b'2016-02-16' b'2016-01-25']
# presc_dept          :[b'IMH' b'OL' b'NR' b'IMR' b'OT' b'CCVSC' b'IME' b'CCVSC' b'IME' b'OT'
#  b'NP' b'GIC' b'RH' b'DS' b'OS' b'OT' b'OT' b'CCVSC' b'OT' b'IME' b'IMH'
#  b'OT' b'OT' b'GIC' b'IMH' b'IMN' b'OS' b'OT' b'NR' b'GIC' b'UR' b'CCVSC']
# order_date          :[b'2016-01-25' b'2016-01-11' b'2016-01-27' b'2016-01-22' b'2016-01-25'
#  b'2016-03-31' b'2016-03-23' b'2016-06-10' b'2016-02-03' b'2016-02-15'
#  b'2016-01-15' b'2016-04-11' b'2016-02-01' b'2016-01-29' b'2016-02-15'
#  b'2016-04-27' b'2016-03-17' b'2016-02-23' b'2016-01-04' b'2016-03-23'
#  b'2016-03-21' b'2016-01-12' b'2016-01-19' b'2016-01-19' b'2016-02-05'
#  b'2016-03-16' b'2016-01-14' b'2016-04-28' b'2016-02-04' b'2016-03-16'
#  b'2016-02-16' b'2016-01-25']
# presc_code          :[b'E109' b'H931' b'K719' b'K0539' b'H2690' b'G4090' b'H0411' b'E148'
#  b'H4019' b'H101' b'G309' b'J310' b'H360' b'K028' b'J189' b'E1121' b'S610'
#  b'I509' b'J47' b'H360' b'G441' b'H2691' b'H360' b'K828' b'E041' b'N289'
#  b'M2321' b'H101' b'H2690' b'K219' b'E149' b'H360']
# presc_information   :[b'IDDM without complications' b'Tinnitus'
#  b'Toxic liver disease, unspecified' b'Periodontitis NOS'
#  b'Cataract, unspecified, Right'
#  b'Epilepsy, unspecified, Without intractable epilepsy'
#  b'Dry-eye syndrome' b'Unspecified DM with unspecified complications'
#  b'Unspecified open-angle glaucoma' b'Acute atopic conjunctivitis'
#  b"Alzheimer's disease, unspecified" b'Chronic rhinitis'
#  b'Diabetic retinopathy' b'Other dental caries' b'Pneumonia, unspecified'
#  b'Non-insulin-dependent diabetes mellitus, with established diabetic nephropathy(N08.3*)'
#  b'Open wound of finger(s) without damage to nail'
#  b'Heart failure, unspecified' b'Bronchiectasis' b'Diabetic retinopathy'
#  b'Vascular headache, NEC' b'Cataract, unspecified, Left'
#  b'Diabetic retinopathy' b'Other specified diseases of gallbladder'
#  b'Nontoxic single thyroid nodule'
#  b'Disorder of kidney and ureter, unspecified'
#  b'Derangement of meniscus due to old tear or injury, medial meniscus'
#  b'Acute atopic conjunctivitis' b'Cataract, unspecified, Right'
#  b'Gastro-oesophageal reflux disease without oesophagitis'
#  b'Unspecified DM without complications' b'Diabetic retinopathy']
# order_code          :[b'XXIGLY13S' b'CNZEP' b'CLOPID' b'HEDER25' b'KREME-K' b'RASUBI1Z'
#  b'HURD1D8-T' b'EPROHTZ' b'XIBAND3' b'LAMO50' b'DVALP1SP' b'PSUTRI'
#  b'MYRTIL' b'ROSUV20' b'LIMAPR5' b'PERIND' b'MCPLX5' b'UDCA3' b'CODENAL'
#  b'TRIFLU' b'NORT1' b'LOFLO-T' b'PSTIG60' b'RABEP20' b'THEOBR3' b'CLOPID'
#  b'HCQ200' b'OLOPA-T' b'DONEP10' b'JOINS' b'PD5' b'OMEGA31']
# order_name          :[b'insulin glycine rh 100 IU/mL 3mL' b'Clonazepam 0.5mg'
#  b'Clopidogrel 75mg' b'Hedera helix 30% 25mg' b'Kremezine 2g' b'AU-F tab'
#  b'Hyaluronate 0.1% 0.8ml 30ea/box' b'Eprosartan 600mg/HCTZ 12.5mg'
#  b'Bonviva inj 3mg/3ml (PFS)' b'Lamotrigine 50mg' b'Divalproex 125mg'
#  b'Pseudoephedrine 60mg/Triprolidine 2.5mg' b'Vaccinium myrtillus'
#  b'Rosuvastatin 20mg' b'Opast 5mcg tab' b'Perindopril 4mg'
#  b'Cephamethyl 500mg' b'Ursa 300mg tab' b'Codenal tab.*'
#  b'Disgren 300mg cap' b'Nortriptyline 10mg' b'Levofloxacin 0.5% 5ml'
#  b'Pyridostigmine 60mg' b'rabeprazole  20mg' b'Theobromine 300mg'
#  b'Clopidogrel 75mg' b'Oxiklorin 200mg Tab' b'Olopatadine 0.1% 5ml'
#  b'Donepezil 10mg' b'Joins* tab' b'Prednisolon 5mg'
#  b'Omega-3-acid ethyl esters 90']
# medic_duration      :[  1   7  12  91  60  90   1  91   1  35  28   7   6 150  21 100   5  60
#    7   4   7   1  60  28  14  35  30   1  91  30  60  98]
# label: [1 2 1 2 3 2 4 1 1 2 1 2 2 1 2 1 3 3 3 2 2 4 1 1 2 1 3 2 1 3 1 1]

# %%
contri_var = result.columns[result.dtypes!='object']

# %%
list(contri_var)
# Out:
# ['order', 'patient_number', 'sum_medic_count', 'medic_duration']

# %%
class PackNumericFeatures(object):
    def __init__(self, names):
        self.names = names

    def __call__(self, features, labels):
        numeric_freatures = [features.pop(name) for name in self.names]
        numeric_features = [tf.cast(feat, tf.float32) for feat in numeric_freatures]
        numeric_features = tf.stack(numeric_features, axis=-1)
        features['numeric'] = numeric_features
        
        matches = tf.greater_equal(3, labels)
        onehot = tf.cast(matches, tf.float32)
        labels = onehot
        
        return features, labels

# %%
NUMERIC_FEATURES = list(contri_var)
NUMERIC_FEATURES
# Out:
# ['order', 'patient_number', 'sum_medic_count', 'medic_duration']

# %%
packed_train_data = raw_train_data.map(PackNumericFeatures(NUMERIC_FEATURES))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-489-bd81ef5e4ae4> in <module>
# ----> 1 packed_train_data = raw_train_data.map(PackNumericFeatures(NUMERIC_FEATURES))
#
# ~\Anaconda3\envs\ilhyun\lib\site-packages\tensorflow_core\python\data\ops\dataset_ops.py in map(self, map_func, num_parallel_calls)
#    1209     """
#    1210     if num_parallel_calls is None:
# -> 1211       return MapDataset(self, map_func, preserve_cardinality=True)
#    1212     else:
#    1213       return ParallelMapDataset(
#
# ~\Anaconda3\envs\ilhyun\lib\site-packages\tensorflow_core\python\data\ops\dataset_ops.py in __init__(self, input_dataset, map_func, use_inter_op_parallelism, preserve_cardinality, use_legacy_function)
#    3414         self._transformation_name(),
#    3415         dataset=input_dataset,
# -> 3416         use_legacy_function=use_legacy_function)
#    3417     variant_tensor = gen_dataset_ops.map_dataset(
#    3418         input_dataset._variant_tensor,  # pylint: disable=protected-access
#
# ~\Anaconda3\envs\ilhyun\lib\site-packages\tensorflow_core\python\data\ops\dataset_ops.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#    2693       resource_tracker = tracking.ResourceTracker()
#    2694       with tracking.resource_tracker_scope(resource_tracker):
# -> 2695         self._function = wrapper_fn._get_concrete_function_internal()
#    2696         if add_to_graph:
#    2697           self._function.add_to_graph(ops.get_default_graph())
#
# ~\Anaconda3\envs\ilhyun\lib\site-packages\tensorflow_core\python\eager\function.py in _get_concrete_function_internal(self, *args, **kwargs)
#    1852     """Bypasses error checking when getting a graph function."""
#    1853     graph_function = self._get_concrete_function_internal_garbage_collected(
# -> 1854         *args, **kwargs)
#    1855     # We're returning this concrete function to someone, and they may keep a
#    1856     # reference to the FuncGraph without keeping a reference to the
#
# ~\Anaconda3\envs\ilhyun\lib\site-packages\tensorflow_core\python\eager\function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    1846     if self.input_signature:
#    1847       args, kwargs = None, None
# -> 1848     graph_function, _, _ = self._maybe_define_function(args, kwargs)
#    1849     return graph_function
#    1850
#
# ~\Anaconda3\envs\ilhyun\lib\site-packages\tensorflow_core\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    2148         graph_function = self._function_cache.primary.get(cache_key, None)
#    2149         if graph_function is None:
# -> 2150           graph_function = self._create_graph_function(args, kwargs)
#    2151           self._function_cache.primary[cache_key] = graph_function
#    2152         return graph_function, args, kwargs
#
# ~\Anaconda3\envs\ilhyun\lib\site-packages\tensorflow_core\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    2039             arg_names=arg_names,
#    2040             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 2041             capture_by_value=self._capture_by_value),
#    2042         self._function_attributes,
#    2043         # Tell the ConcreteFunction to clean up its graph once it goes out of
#
# ~\Anaconda3\envs\ilhyun\lib\site-packages\tensorflow_core\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     913                                           converted_func)
#     914
# --> 915       func_outputs = python_func(*func_args, **func_kwargs)
#     916
#     917       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~\Anaconda3\envs\ilhyun\lib\site-packages\tensorflow_core\python\data\ops\dataset_ops.py in wrapper_fn(*args)
#    2687           attributes=defun_kwargs)
#    2688       def wrapper_fn(*args):  # pylint: disable=missing-docstring
# -> 2689         ret = _wrapper_helper(*args)
#    2690         ret = structure.to_tensor_list(self._output_structure, ret)
#    2691         return [ops.convert_to_tensor(t) for t in ret]
#
# ~\Anaconda3\envs\ilhyun\lib\site-packages\tensorflow_core\python\data\ops\dataset_ops.py in _wrapper_helper(*args)
#    2632         nested_args = (nested_args,)
#    2633
# -> 2634       ret = autograph.tf_convert(func, ag_ctx)(*nested_args)
#    2635       # If `func` returns a list of tensors, `nest.flatten()` and
#    2636       # `ops.convert_to_tensor()` would conspire to attempt to stack
#
# ~\Anaconda3\envs\ilhyun\lib\site-packages\tensorflow_core\python\autograph\impl\api.py in wrapper(*args, **kwargs)
#     235       except Exception as e:  # pylint:disable=broad-except
#     236         if hasattr(e, 'ag_error_metadata'):
# --> 237           raise e.ag_error_metadata.to_exception(e)
#     238         else:
#     239           raise
#
# KeyError: in converted code:
#
#     <ipython-input-487-d8ac8ee5271e>:6 __call__  *
#         numeric_freatures = [features.pop(name) for name in self.names]
#     C:\Users\hyun\Anaconda3\envs\ilhyun\lib\site-packages\tensorflow_core\python\autograph\impl\api.py:396 converted_call
#         return py_builtins.overload_of(f)(*args)
#
#     KeyError: 'sum_medic_count'

# %%
desc = result[NUMERIC_FEATURES].describe()

# %%
desc
# Out:
#                order  patient_number  sum_medic_count  medic_duration
# count  479230.000000    4.792300e+05    479230.000000   479230.000000
# mean   239614.500000    1.044013e+07         1.829710       14.948079
# std    138341.929089    2.235415e+05         1.063725       26.829278
# min         0.000000    1.000010e+07         1.000000        1.000000
# 25%    119807.250000    1.024311e+07         1.000000        1.000000
# 50%    239614.500000    1.052012e+07         2.000000        4.000000
# 75%    359421.750000    1.064061e+07         2.000000       14.000000
# max    479229.000000    1.071575e+07        24.000000      365.000000

# %%
MEAN = np.array(desc.T['mean'])

# %%
STD = np.array(desc.T['std'])

# %%
def normalize_numeric_data(data,mean,std):
    return (data-mean)/std

# %%
import functools

# %%
normalizer = functools.partial(normalize_numeric_data,mean=MEAN,std=STD)
numeric_column = tf.feature_column.numeric_column('numeric',normalizer_fn=normalizer,shape=[len(NUMERIC_FEATURES)])

# %%
numeric_columns = [numeric_column]
numeric_column
# Out:
# NumericColumn(key='numeric', shape=(4,), default_value=None, dtype=tf.float32, normalizer_fn=functools.partial(<function normalize_numeric_data at 0x000001E638794048>, mean=array([2.39614500e+05, 1.04401327e+07, 1.82971016e+00, 1.49480792e+01]), std=array([1.38341929e+05, 2.23541511e+05, 1.06372516e+00, 2.68292779e+01])))

# %%
categorical = list(result.columns[result.dtypes == 'object'])
categorical
# Out:
# ['presc_date',
#  'presc_dept',
#  'order_date',
#  'presc_code',
#  'presc_information',
#  'order_code',
#  'order_name']

# %%
def get_keys(data,feature):
    return list(result[feature].value_counts().keys())

# %%
get_keys(result,"order_code")
# Out:
# ['XNS50C',
#  'LDPIZ-S',
#  'TROPHE-T',
#  'BIOF250-K',
#  'CP4PHE1-S',
#  'XDNK2',
#  'BUD2-RP',
#  'PD5',
#  'IBUP-S',
#  'XNS1L',
#  'CODENAL',
#  'APH6ER',
#  'APH32-S',
#  'PSUTRI-S',
#  'NAPRO5SOM',
#  'CNZEP',
#  'ASP1PR',
#  'LCTZIN',
#  'COPIVY-S',
#  'COPIVY-K',
#  'VAS10-O',
#  'AMBR-S',
#  'RASUBI1W',
#  'XAMBR15',
#  'CAROLF',
#  'ACECL',
#  'HURON15-T',
#  'TULOB.5-H',
#  'XNS100',
#  'QUET25',
#  'PDV-CR',
#  'DIBUP',
#  'MOM514-NS',
#  'TAMSUD',
#  'ATORV10',
#  'SKDASE',
#  'NORT1',
#  'NORV',
#  'MGO5',
#  'XPCMOL',
#  'REBAM',
#  'GINKB80',
#  'CELEB',
#  'METFOR5XR',
#  'PSEP',
#  'HURON15W-T',
#  'PREGA75',
#  'CLOPID',
#  'PANTO20W',
#  'DEXLANS3',
#  'REBAM1U',
#  'LZPAM',
#  'LINAGL5',
#  'RASUBID',
#  'MEQUIT',
#  'MONTEL10',
#  'LOFLO-T',
#  'CPDXM',
#  'STILL',
#  'BEPOT10',
#  'ACYST2',
#  'AMX7CL-S',
#  'ACEBR100',
#  'XNS500',
#  'EPERIS',
#  'LAFUT10',
#  'LAYLA',
#  'MET1GXR',
#  'AMBR30',
#  'TRIME300S',
#  'FURO',
#  'ALPRA2',
#  'AST1W',
#  'XDNK35',
#  'CTAMET5W',
#  'XMEXO',
#  'FEROBA',
#  'DULOX30',
#  'TRIME-S',
#  'DIQUA-T',
#  'ATORV20',
#  'CPDXM-S',
#  'MOXIFL-T',
#  'XTAMC40',
#  'SALB-NB',
#  'CACA5D10',
#  'JOINS',
#  'TRAMAPH3Y',
#  'TULOB1-H',
#  'FL-T',
#  'HEDER25',
#  'PENIR',
#  'GLIMEP2',
#  'ECTAL',
#  'NAPRO5SOM2',
#  'ESOME20',
#  'ZALTOP',
#  'XTRAM50',
#  'RASUBI1Z',
#  'XMIDA5G',
#  'TMETAZSR',
#  'IMPACP',
#  'GLICL30',
#  'RASUBIDW',
#  'METFOR5',
#  'LCTZIN-S',
#  'MCPLX5',
#  'CLAR5XL',
#  'MOSAP',
#  'LZPAM1',
#  'LIMAPR5',
#  'XKROL',
#  'DONEP5',
#  'MYRTIL',
#  'THEOBR3',
#  'XDXM',
#  'DONEP10',
#  'METOC',
#  'APH3TR3ER',
#  'CORPHA30',
#  'DESLORA5',
#  'PROP10',
#  'NAPROX',
#  'MPD4',
#  'XXIGLY13S',
#  'SALB-RS',
#  'PSUTRI',
#  'CLAR-S',
#  'PELARG',
#  'MELOX7.5W',
#  'SULODE',
#  'ENKLE-NS',
#  'ATORV10Y',
#  'CDINIR-W',
#  'ALCARN500',
#  'BZD.1-GA',
#  'MEDIL',
#  'ATORV40',
#  'XRAN50',
#  'CDTREN',
#  'HURD1D8-T',
#  'LOSA50',
#  'RABEP20',
#  'SARPOG1W',
#  'FOLI',
#  'PIMEC-CR1',
#  'BISOPR2.5',
#  'SUCRA-K',
#  'RISPE.5H',
#  'IPRAT-RS',
#  'PROPR40',
#  'CALFOS4Y',
#  'THIOCT4',
#  'FLUNA',
#  'SILYM',
#  'DIME5',
#  'FEXO180',
#  'ERDOS',
#  'LANS15LFDT',
#  'LDPIZ6W',
#  'MGO2',
#  'HXZIN-S',
#  'XDKPROF',
#  'ROSUV10W',
#  'CODE20',
#  'XLID1',
#  'POLAZINC',
#  'XCTXM',
#  'FAMOD',
#  'ACYST-A',
#  'LACRHA',
#  'XGPYRO',
#  'XXHYAL60',
#  'BISOPR',
#  'SIT100M1XR',
#  'SPANTO20',
#  'ASP1',
#  'TRIME',
#  'XREMIF1',
#  'SPIR',
#  'LACTU15-K',
#  'XD5W50',
#  'T450',
#  'XMVI',
#  'ITOPRI',
#  'RENAL',
#  'AMLODB10',
#  'MCPLX5T',
#  'XNS250',
#  'XCTXM1G',
#  'TRAZO',
#  'XMIDA5',
#  'PANCR457',
#  'XPETH50',
#  'QUET100',
#  'XCZEDO',
#  'E400',
#  'EPERIS7',
#  'PANCRON',
#  'ALLOP',
#  'DILAT12',
#  'DEXA-GA',
#  'OFLO-TO',
#  'ASP1PRW',
#  'XNS20',
#  'DC',
#  'LOXFEN',
#  'DILAT6',
#  'UDCA1',
#  'COUGH-S',
#  'MUPIR-O',
#  'XAMPSUL7',
#  'CECLOR',
#  'INOFRE-S',
#  'NITR',
#  'ESCITA5',
#  'XCTRX2',
#  'SERTR',
#  'PPEX.25',
#  'PGCIN',
#  'XMVP12',
#  'SIT50M5',
#  'PENNEL',
#  'XCPENIR',
#  'NICORA',
#  'XHS',
#  'LANS30LFDT',
#  'XXINFL5N',
#  'DVALP2ER',
#  'TRAM50',
#  'DEXLANS6',
#  'ZOLPID',
#  'XHUMA10',
#  'CLOPID75',
#  'ROXIT50',
#  'ESOMST20',
#  'CIMETR',
#  'CLAR50-S',
#  'THIOS',
#  'ANYTAL',
#  'PEG3PS-W',
#  'PANTOP20',
#  'COIBAPH',
#  'METFOR1G',
#  'GABAP1',
#  'DVALP1SP',
#  'AMXCL6',
#  'FLUC-CR',
#  'CDINIR',
#  'BACL10W',
#  'XROCU50',
#  'METFOR8',
#  'HURON-T',
#  'PVP5-GA',
#  'CACA1D10',
#  'TIZAN',
#  'AFLOQ',
#  'TALNIF',
#  'XCZOL',
#  'OLOPA-T',
#  'MPD-O',
#  'ESOME40',
#  'GLIMEP4',
#  'AZITH',
#  'MOMET-CR',
#  'HUR18D8-T',
#  'XAMXCL1.2',
#  'ROSUV10',
#  'TELMIS40',
#  'EBAST',
#  'SMEC-K',
#  'DILT90',
#  'FENOF160',
#  'XD5S',
#  'PREGA150',
#  'GLICL60MR',
#  'MEMAN',
#  'INDA1.5',
#  'RAN150W',
#  'XPLASMA',
#  'XPETHG',
#  'CIPR500UR',
#  'ATORV20Y',
#  'FEXPSU',
#  'B6',
#  'ACECL200',
#  'FAMC2',
#  'XTAZOC4W',
#  'XPANTO4',
#  'XGNS150',
#  'INAH',
#  'XRAMOSET',
#  'TULOB.5-HW',
#  'LEVETI2',
#  'CARBO-TG',
#  'SOLIF5',
#  'APH325',
#  'GEMIG50',
#  'XEPHE',
#  'MIRABE5',
#  'XNSTIG',
#  'XMPD40',
#  'BESZYM',
#  'AMIT1',
#  'RFP3',
#  'ROP.25',
#  'PLKAST1W',
#  'CIL100SRC',
#  'XXHUMA3',
#  'PGCIN-S',
#  'HTZ',
#  'XICGR',
#  'OMEP40B',
#  'PGE1',
#  'CIPR2',
#  'TM-TO',
#  'RABEP10',
#  'PERIND',
#  'MUPIR1W-O',
#  'AMX5W',
#  'LCTZINPSU',
#  'COLCH',
#  'XHEPAR5',
#  'DDP2W',
#  'XHYOS',
#  'OSELTAM',
#  'GINCOSAN',
#  'UDCA2',
#  'XD5W100',
#  'NIFED40C',
#  'XGM80',
#  'OXCARB3',
#  'KREME-K',
#  'T4',
#  'SIT50M8',
#  'XNEFOP20',
#  'CELEB2W',
#  'HXZIN10W',
#  'PCYCL',
#  'LEVETI5',
#  'XVECUR10Y',
#  'MONTEL10W',
#  'ROSUV20W',
#  'DOXOFY',
#  'NB5',
#  'LITH',
#  'EMB',
#  'AZEL',
#  'XPROPO115W',
#  'CDTREN-W',
#  'ACYST-S',
#  'OFLO-E',
#  'RISP1',
#  'METR',
#  'EUPATIL',
#  'DVALP5ER',
#  'PIOGLI15',
#  'PRAV40',
#  'ISMN20',
#  'DULOX60',
#  'XXHUMA253',
#  'OSELTAM30',
#  'CLAR5',
#  'ALE70D53',
#  'XNICAR',
#  'AMPSUL',
#  'CILOS200',
#  'XPLASMA1W',
#  'XCPIRA',
#  'DORZOT-T',
#  'SIT50M10',
#  'GABAP3Y',
#  'VALSAR',
#  'XMETR500',
#  'DILT30',
#  'MEGES4-K10',
#  'NEBIV5',
#  'DAPAG10',
#  'LANSOP15',
#  'AMLODS2.5',
#  'SMEC-S',
#  'TIBOL2.5',
#  'ENTER150',
#  'CIN2DIM4',
#  'AM5TEL40',
#  'INDOM25',
#  'XFENT100',
#  'BLICHEN5',
#  'BRIM.1-T',
#  'CZPAM',
#  'MIRTA7',
#  'DIACER5W',
#  'PANTOP40',
#  'ALCAR500V',
#  'APH6TR7ER',
#  'LANSOPR15',
#  'CENTRUMA',
#  'XPTS500',
#  'PIREN-T',
#  'XFEN50',
#  'OLMET20',
#  'ALGIN-K',
#  'DILAT3',
#  'LINAGL2M5',
#  'RACEC1-K',
#  'MEGES4-K20',
#  'BZD.3-A',
#  'FEXO120',
#  'MPHEN10',
#  'ALCAFT-T',
#  'XBPCA.5H4',
#  'MTPROL',
#  'MONTEL4CH',
#  'MZ',
#  'MIRTZ15',
#  'XNS100P',
#  'TACRO.1-O',
#  'XCIPR4',
#  'XCIMETR',
#  'XOMAP72',
#  'ESCITA20',
#  'CLOPIB75',
#  'DOMPM',
#  'XPCMOL1P',
#  'VORTI5',
#  'ROSUV5Y',
#  'WARF2',
#  'TIROP',
#  'LDB250',
#  'GABAP3',
#  'DGX',
#  'XHEPAR1',
#  'MTX2.5',
#  'PINAV',
#  'DILAT25',
#  'CL75A100',
#  'LOSA100',
#  'CENTRUMSLA',
#  'SITAG100',
#  'BUPRO1W',
#  'RAN300',
#  'BZYD1-NB',
#  'SCZOL-CR',
#  'AZITH-S',
#  'XD5W5',
#  'XFEN500P',
#  'LDPIZ',
#  'PZA5',
#  'XCTXM2G',
#  'XPSTIG',
#  'XCZEDO2G',
#  'SERTR50',
#  'X10IFUS5',
#  'APIXA2',
#  'DDP5',
#  'XB12',
#  'TOB-T',
#  'KTOPEL-H',
#  'TELMIS80',
#  'CY-T',
#  'XFURO',
#  'LOFLO500',
#  'XNITR10',
#  'TICAG90',
#  'LCLOPE-P',
#  'FLF5120-N',
#  'XIGLY10',
#  'LSULPR',
#  'XESOME40',
#  'ISDN40',
#  'EZESIM10',
#  'ALPRA2W',
#  'PSTYR-K',
#  'T4150',
#  'V2F1-D',
#  'XB1',
#  'XPALON75',
#  'XMELPRO2',
#  'ALVESIM6W',
#  'PDF10-T',
#  'XD5S5',
#  'TIANEP',
#  'XAZITH',
#  'ROSUV10Y',
#  'XD5W',
#  'PGI2',
#  'LATAN-T',
#  'LINAGL2M8',
#  'CLOPID75Z',
#  'BIMAT.1-T',
#  'KPROF-GL',
#  'TIOTR5-Y',
#  'MONTEL5CH',
#  'B1F120-A',
#  'AMIOD',
#  'MELOX15W',
#  'CILN10',
#  'XBH',
#  'PSTYR5-KS',
#  'NIFEDO60',
#  'ATORV10W',
#  'LOCE5-NL',
#  'TZOS5',
#  'XXINFL5SH',
#  'TACRO-O',
#  'KCZOL-CR',
#  'BOS-L',
#  'LID700-H',
#  'VMED50',
#  'XCMN9GE1',
#  'GODEX',
#  'CILOS50',
#  'NAFR100X',
#  'CICLE5-NS',
#  'ROSUV20',
#  'LOPEROX',
#  'CH.1-GA',
#  'HCQ200',
#  'CAACET',
#  'XXIGLY4',
#  'PITAV2',
#  'PRAV20',
#  'BUPRE5-H',
#  'XPHEPH1',
#  'ES.05-GL',
#  'EZEROSU5',
#  'XGD5W2',
#  'XFAMO',
#  'METFOR5XRW',
#  'IRSOG4',
#  'CDP10',
#  'EMLA-CR',
#  'TNAF',
#  'OLMET40',
#  'IRB1ATO1',
#  'XEPIN',
#  'LDC125',
#  'TEPREN',
#  'TI5BR10-T',
#  'PSTYR5-K',
#  'VALAC5',
#  'METFOR2',
#  'XCMTAZ',
#  'OMEGA31W',
#  'GEMIG5M1',
#  'DIBUP-S',
#  'ROSUV5W',
#  'SALAZ',
#  'ZOLMIT',
#  'LOBEG',
#  'XVARIZO',
#  'SARPOG3',
#  'EZESIM20',
#  'XMORPS5',
#  'BISA-P',
#  'AM5LO50',
#  'CILN5',
#  'ESCIT10',
#  'FIMAS60',
#  'SUMAT',
#  'TRAMAPH3X',
#  'XKETA5',
#  'ARIPIP2',
#  'AZOS10XL1W',
#  'OSELTAM45',
#  'ALCA500-K',
#  'CALCIT.25',
#  'NIFEDO30',
#  'CHR-S',
#  'T450W',
#  'XLID2W',
#  'TRANEX',
#  'MIRTZ30',
#  'LOTEP-T',
#  'SIT50M5XR',
#  'FEN1-H',
#  'CANDES8',
#  'XD10W',
#  'ROXIT150',
#  'XPNEUM13A',
#  'LAMO25',
#  'DILAT16SR',
#  'GEMIG5M5',
#  'MOSAP5Y',
#  'EROTRI',
#  'AMX-S',
#  'TREST',
#  'XXEPOA10K',
#  'OLOP.2-T',
#  'OXCON5',
#  'ROSUV5',
#  'IBUP',
#  'SYLCON',
#  'AMLATO10',
#  'MESOG50',
#  'AMXCL3',
#  'CIPO25',
#  'AML50OL20',
#  'RIVAR15',
#  'RIVAR20',
#  'UREA-CR',
#  'BSSP-L',
#  'CRADIN5',
#  'XNITR10F',
#  'PIOGLI30',
#  'MOXIFL',
#  'AZOS10XL',
#  'TRIHE',
#  'XSMOFKP14',
#  'LOSA100W',
#  'FLUC',
#  'RWACHOL',
#  'ACYC-CR',
#  'XMCARBA5',
#  'XD10W5',
#  'XRPCA7',
#  'RASAG1',
#  'XXINFLT5',
#  'RISP2',
#  'POLMACO2',
#  'X6PAMI5',
#  'THGLC-CR',
#  'CLZA100',
#  'ESCITA15',
#  'AM5LO100',
#  'ISMN60',
#  'ATEN25',
#  'FOSFO-K',
#  'B1F60-TH',
#  'XDICLOF',
#  'TULOB2-H',
#  'VALSAR160',
#  'RALOX60',
#  'KALLID50W',
#  'DONEP23',
#  'FENOF135',
#  'XAMP5',
#  'XACYC',
#  'EZEATO20',
#  'AM5TEL80',
#  'MYP-T',
#  'BNCHOL25',
#  'CALFOS4Z',
#  'MELATO2',
#  'PPEX.5',
#  'SAXAG5M1',
#  'XMAROA22',
#  'ZOLP6CR',
#  'GO75-S',
#  'XXHUMA553',
#  'CMCYS2-S',
#  'ATEN50',
#  'XLZPAM2',
#  'CIPRHC-E',
#  'BUP10',
#  'SAXAG5',
#  'X10CAFS5',
#  'PANTO40W',
#  'IRBESA1',
#  'XAMPSUL15',
#  'CACA1D4',
#  'XCTOC100',
#  'XFOMSP9',
#  'VMED',
#  'VORTI10',
#  'CHOLA400',
#  'XXIPA73',
#  'LOSAHTZ',
#  'AMX2',
#  'AMLODCA',
#  'SIMVCR20',
#  'G2MET5',
#  'CANDES16',
#  'PDCARB-O',
#  'TNAF-CR',
#  'TENOF300W',
#  'TENELI20',
#  'B1F120-TH',
#  'FLEC',
#  'KTIFEN',
#  'X20M1X',
#  'TIMO-T',
#  'RISPE1H',
#  'HCQ100',
#  'TAFLUS15-T',
#  'XIBAND3',
#  'TEL4ROSU1',
#  'LOSA50W',
#  'X20AL1S',
#  'MEQUIT-S',
#  'XC500',
#  'XHD',
#  'MPD-LT',
#  'CTZIN',
#  'XCTRX',
#  'CXIM-W',
#  'XCAGL',
#  'BUPRE10-H',
#  'AMLODS5',
#  'XAMIOD',
#  'CLTHC1W-CR',
#  'HYOS',
#  'HCORT1-L',
#  'XSUGAM2',
#  'FENOF160M',
#  'WARF5',
#  'HURON18-T',
#  'SIMV20',
#  'PERIND8',
#  'AGIO-K',
#  'LINAGL2M10',
#  'XXEPOA4K',
#  'VOGLIB3',
#  'XIRONSU',
#  'VENL37P',
#  'ATORV10Z',
#  'PRAV10',
#  'XCLM',
#  'PHAZYM',
#  'XNORE10',
#  'XHS5',
#  'XCPZSUL',
#  'DOR2T5-S',
#  'FORMO1-S',
#  'EBAPSU',
#  'DNP-TO',
#  'HCOR10',
#  'CIME2',
#  'KCON6',
#  'XXEPOA6K',
#  'XVANCO1',
#  'CLOPIR75',
#  'ZONISA',
#  'XRANIB.5',
#  'BCOM',
#  'NAFTA',
#  'X10HEP5',
#  'XD50W1',
#  'OLOP.2W-T',
#  'TRAM100',
#  'XFOMSP14',
#  'AM10L50',
#  'XHNS',
#  'XACYST',
#  'KTIFEN-S',
#  'SPANTO10',
#  'BISAD',
#  'XOXYT',
#  'ARIPIP5',
#  'AMISUL1',
#  'PREPH-O',
#  'XIGLUL10',
#  'XCTIAM',
#  'OMEGA31',
#  'OMEP10',
#  'CPIR15W-SH',
#  'EZEROSU10',
#  'HARMO2W-B',
#  'XGOSE',
#  'MONTEL10X',
#  'SAXAG5M5',
#  'ISDN300-A',
#  'TRIFLU',
#  'AM5LO50W',
#  'IMIDA.1',
#  'ACECL1X',
#  'XCMINX',
#  'BEPOT9',
#  'THIOCT6X',
#  'B320F60-TH',
#  'OLAN2.5',
#  'MPD-CR',
#  'ALEND70',
#  'CUROX2Y',
#  'G1MET5',
#  'XCTRX5',
#  'LANSOP',
#  'FAMC7',
#  'IRB3ATO1',
#  'AJ',
#  'OLMET10',
#  'FINAS5',
#  'DILAT8SR',
#  'XXHINFB',
#  'GALTAS-W',
#  'AML5VA8',
#  'XXBEMI35',
#  'XXDTPP',
#  'UDCA3',
#  'DILAT32SR',
#  'XHURON75',
#  'SAL200-A',
#  'NACL-W',
#  'TANDOS5',
#  'X10PROA5',
#  'XPNEUMO13',
#  'GABAP6',
#  'VAREN.5',
#  'CUDCA250',
#  'AM2TEL40',
#  'DDS100',
#  'CANDES16W',
#  'RAN75',
#  'PANTO40',
#  'CUROX2X',
#  'RIVAS10-H',
#  'XXDARBE120',
#  'BSS-L',
#  'XXENOX40',
#  'NALTRE',
#  'PITAV2W',
#  'TULOB1-HW',
#  'PLK100-W',
#  'FL.55-T',
#  'VID50M1000',
#  'XXEPOA8K',
#  'XHEP100PM',
#  'OXYC10N5',
#  'XXIDET3',
#  'XLID2',
#  'TEL8HTZ',
#  'ACLID60-D',
#  'VALPR-S',
#  'XC10W',
#  'MOLSIDO4',
#  'IRONA-K',
#  'AML5VA16',
#  'LEVETI2Y',
#  'XPSPA',
#  'DABIG150',
#  'EZEATO10',
#  'THROM-W',
#  'ALPRA5',
#  'ROTARIX-S',
#  'RABEP10Y',
#  'BCG-H',
#  'XLEVET500',
#  'F2S5-AK',
#  'FIMAS120',
#  'HDR',
#  'OLM2ROSU1',
#  'VID50M850',
#  'DANTR25',
#  'AZAT50Y',
#  'PGCIND',
#  'XTRIPTO3',
#  'DABIG110',
#  'AML5OL40',
#  'APIXA5',
#  'XXIDEGL3',
#  'GEMIG2M5',
#  'XPROG',
#  'TAMSU.2D',
#  'LOFLO250',
#  'ATORV20Z',
#  'DFCORT1W-O',
#  'MYRT300',
#  'LAMO100',
#  'DXM',
#  'CXIM',
#  'FLUC-S',
#  'RACEC3-K',
#  'XXNPH3',
#  'LDB125D',
#  'DIENOG2',
#  'LEVETI1G',
#  'RASUBI1Y',
#  'XLOFLO5',
#  'OXYC5N2',
#  'XCALCIT1',
#  'AMX7CL',
#  'PVP-VS',
#  'ITCON',
#  'TRANIL',
#  'XHBV10',
#  'VALPR5',
#  'XHCS100',
#  'DONEP10C',
#  'ISMN40',
#  'EZEATO40',
#  'ETIZOL.5',
#  'CACB500',
#  'COTRIM',
#  'CAL1-L',
#  'TN-T',
#  'FOXET20D',
#  'PSTIG60',
#  'XAFLIB',
#  'SIM2FENOF',
#  'MPRG10',
#  'SILOD4W',
#  'MELOX7.5X',
#  'STILLX',
#  'X10PROA2',
#  'FEBUX40',
#  'PFENON2SR',
#  'CANDHTZ',
#  'OCTYL40',
#  'DOMP-S',
#  'TEL8ROSU1',
#  'PERAMP2',
#  'XNFMOS10',
#  'XHR10',
#  'CLM',
#  'IPRAT-N',
#  'AM5OL4HTZ',
#  'AVOCA300',
#  'LAMO50',
#  'EESTDROS',
#  'TOPIR25',
#  'SILDC100',
#  'TORAS5',
#  'ITOPRI5W',
#  'XHYALU15W',
#  'BRH',
#  'XXCTRX2',
#  'PAROXCR',
#  'OLM2ROSU5',
#  'MONTEL4-K',
#  'CILOS100S',
#  'SIT50M1XR',
#  'X2TAUR2',
#  'XHBV20',
#  'ACYST1',
#  'XBABA',
#  'XD20W20',
#  'XDOPA4D2',
#  'ILAPR10',
#  'MISOP2',
#  'LERCAN',
#  'XLABETA',
#  'RIVAS5-H',
#  'ZOLP12CR',
#  'YAL-L',
#  'PRAV40W',
#  'FIMA6HTZ',
#  'RETAP-O',
#  'XHPD',
#  'RAMIP2',
#  'COUGH-K',
#  'FEBUX80',
#  'NEBIV2',
#  'IRSOG2ODT',
#  'NS-L',
#  'RIFAX200',
#  'LEVE100-S',
#  'EZETIM',
#  'BROMF-T',
#  'MELOX15Y',
#  'AM10OL4HTZ',
#  'AM5OL2HTZ',
#  'OLAN5',
#  'BUSP5',
#  'ISDN120',
#  'PDCARB-L',
#  'AMX7CL5W',
#  'HARMO5W-B',
#  'XLHRH',
#  'NICER10',
#  'CELEB1W',
#  'XVANC1G',
#  'ENTEC.5',
#  'LORCAS',
#  'XMPD1',
#  'RFP1',
#  'OLM20HC12',
#  'ACYC',
#  'BRIMB-T',
#  'G2MET5EX',
#  'CLZA25',
#  'PSYL-K',
#  'ROP1',
#  'FESTOPR4',
#  'XK40',
#  'LNORG52',
#  'PDV-60L',
#  'CECLO-S',
#  'BUP',
#  'DZOS4XL',
#  'NEBIV5W',
#  'ESOMST40',
#  'XCISACUR',
#  'XXTDAP',
#  'CACI1D4',
#  'TADAL5W',
#  'TEL4HTZ',
#  'XNB84',
#  'MEGES10-K6',
#  'ONG-V',
#  'GINKB80W',
#  'HCQ15',
#  'VAREN1',
#  'METR-GL',
#  'XTNAPER9',
#  'TOSUFL',
#  'ZOLPID5',
#  'PANTO20',
#  'RAMIP5',
#  'MENI',
#  'AZAT50X',
#  ...]

# %%
def get_categories(data,c_list):
    category={}
    for i in c_list[:-1]:
        category[i] = get_keys(data,i)
    return category

# %%
CATEGORIES = get_categories(result, categorical)
CATEGORIES['order_code']
# Out:
# ['XNS50C',
#  'LDPIZ-S',
#  'TROPHE-T',
#  'BIOF250-K',
#  'CP4PHE1-S',
#  'XDNK2',
#  'BUD2-RP',
#  'PD5',
#  'IBUP-S',
#  'XNS1L',
#  'CODENAL',
#  'APH6ER',
#  'APH32-S',
#  'PSUTRI-S',
#  'NAPRO5SOM',
#  'CNZEP',
#  'ASP1PR',
#  'LCTZIN',
#  'COPIVY-S',
#  'COPIVY-K',
#  'VAS10-O',
#  'AMBR-S',
#  'RASUBI1W',
#  'XAMBR15',
#  'CAROLF',
#  'ACECL',
#  'HURON15-T',
#  'TULOB.5-H',
#  'XNS100',
#  'QUET25',
#  'PDV-CR',
#  'DIBUP',
#  'MOM514-NS',
#  'TAMSUD',
#  'ATORV10',
#  'SKDASE',
#  'NORT1',
#  'NORV',
#  'MGO5',
#  'XPCMOL',
#  'REBAM',
#  'GINKB80',
#  'CELEB',
#  'METFOR5XR',
#  'PSEP',
#  'HURON15W-T',
#  'PREGA75',
#  'CLOPID',
#  'PANTO20W',
#  'DEXLANS3',
#  'REBAM1U',
#  'LZPAM',
#  'LINAGL5',
#  'RASUBID',
#  'MEQUIT',
#  'MONTEL10',
#  'LOFLO-T',
#  'CPDXM',
#  'STILL',
#  'BEPOT10',
#  'ACYST2',
#  'AMX7CL-S',
#  'ACEBR100',
#  'XNS500',
#  'EPERIS',
#  'LAFUT10',
#  'LAYLA',
#  'MET1GXR',
#  'AMBR30',
#  'TRIME300S',
#  'FURO',
#  'ALPRA2',
#  'AST1W',
#  'XDNK35',
#  'CTAMET5W',
#  'XMEXO',
#  'FEROBA',
#  'DULOX30',
#  'TRIME-S',
#  'DIQUA-T',
#  'ATORV20',
#  'CPDXM-S',
#  'MOXIFL-T',
#  'XTAMC40',
#  'SALB-NB',
#  'CACA5D10',
#  'JOINS',
#  'TRAMAPH3Y',
#  'TULOB1-H',
#  'FL-T',
#  'HEDER25',
#  'PENIR',
#  'GLIMEP2',
#  'ECTAL',
#  'NAPRO5SOM2',
#  'ESOME20',
#  'ZALTOP',
#  'XTRAM50',
#  'RASUBI1Z',
#  'XMIDA5G',
#  'TMETAZSR',
#  'IMPACP',
#  'GLICL30',
#  'RASUBIDW',
#  'METFOR5',
#  'LCTZIN-S',
#  'MCPLX5',
#  'CLAR5XL',
#  'MOSAP',
#  'LZPAM1',
#  'LIMAPR5',
#  'XKROL',
#  'DONEP5',
#  'MYRTIL',
#  'THEOBR3',
#  'XDXM',
#  'DONEP10',
#  'METOC',
#  'APH3TR3ER',
#  'CORPHA30',
#  'DESLORA5',
#  'PROP10',
#  'NAPROX',
#  'MPD4',
#  'XXIGLY13S',
#  'SALB-RS',
#  'PSUTRI',
#  'CLAR-S',
#  'PELARG',
#  'MELOX7.5W',
#  'SULODE',
#  'ENKLE-NS',
#  'ATORV10Y',
#  'CDINIR-W',
#  'ALCARN500',
#  'BZD.1-GA',
#  'MEDIL',
#  'ATORV40',
#  'XRAN50',
#  'CDTREN',
#  'HURD1D8-T',
#  'LOSA50',
#  'RABEP20',
#  'SARPOG1W',
#  'FOLI',
#  'PIMEC-CR1',
#  'BISOPR2.5',
#  'SUCRA-K',
#  'RISPE.5H',
#  'IPRAT-RS',
#  'PROPR40',
#  'CALFOS4Y',
#  'THIOCT4',
#  'FLUNA',
#  'SILYM',
#  'DIME5',
#  'FEXO180',
#  'ERDOS',
#  'LANS15LFDT',
#  'LDPIZ6W',
#  'MGO2',
#  'HXZIN-S',
#  'XDKPROF',
#  'ROSUV10W',
#  'CODE20',
#  'XLID1',
#  'POLAZINC',
#  'XCTXM',
#  'FAMOD',
#  'ACYST-A',
#  'LACRHA',
#  'XGPYRO',
#  'XXHYAL60',
#  'BISOPR',
#  'SIT100M1XR',
#  'SPANTO20',
#  'ASP1',
#  'TRIME',
#  'XREMIF1',
#  'SPIR',
#  'LACTU15-K',
#  'XD5W50',
#  'T450',
#  'XMVI',
#  'ITOPRI',
#  'RENAL',
#  'AMLODB10',
#  'MCPLX5T',
#  'XNS250',
#  'XCTXM1G',
#  'TRAZO',
#  'XMIDA5',
#  'PANCR457',
#  'XPETH50',
#  'QUET100',
#  'XCZEDO',
#  'E400',
#  'EPERIS7',
#  'PANCRON',
#  'ALLOP',
#  'DILAT12',
#  'DEXA-GA',
#  'OFLO-TO',
#  'ASP1PRW',
#  'XNS20',
#  'DC',
#  'LOXFEN',
#  'DILAT6',
#  'UDCA1',
#  'COUGH-S',
#  'MUPIR-O',
#  'XAMPSUL7',
#  'CECLOR',
#  'INOFRE-S',
#  'NITR',
#  'ESCITA5',
#  'XCTRX2',
#  'SERTR',
#  'PPEX.25',
#  'PGCIN',
#  'XMVP12',
#  'SIT50M5',
#  'PENNEL',
#  'XCPENIR',
#  'NICORA',
#  'XHS',
#  'LANS30LFDT',
#  'XXINFL5N',
#  'DVALP2ER',
#  'TRAM50',
#  'DEXLANS6',
#  'ZOLPID',
#  'XHUMA10',
#  'CLOPID75',
#  'ROXIT50',
#  'ESOMST20',
#  'CIMETR',
#  'CLAR50-S',
#  'THIOS',
#  'ANYTAL',
#  'PEG3PS-W',
#  'PANTOP20',
#  'COIBAPH',
#  'METFOR1G',
#  'GABAP1',
#  'DVALP1SP',
#  'AMXCL6',
#  'FLUC-CR',
#  'CDINIR',
#  'BACL10W',
#  'XROCU50',
#  'METFOR8',
#  'HURON-T',
#  'PVP5-GA',
#  'CACA1D10',
#  'TIZAN',
#  'AFLOQ',
#  'TALNIF',
#  'XCZOL',
#  'OLOPA-T',
#  'MPD-O',
#  'ESOME40',
#  'GLIMEP4',
#  'AZITH',
#  'MOMET-CR',
#  'HUR18D8-T',
#  'XAMXCL1.2',
#  'ROSUV10',
#  'TELMIS40',
#  'EBAST',
#  'SMEC-K',
#  'DILT90',
#  'FENOF160',
#  'XD5S',
#  'PREGA150',
#  'GLICL60MR',
#  'MEMAN',
#  'INDA1.5',
#  'RAN150W',
#  'XPLASMA',
#  'XPETHG',
#  'CIPR500UR',
#  'ATORV20Y',
#  'FEXPSU',
#  'B6',
#  'ACECL200',
#  'FAMC2',
#  'XTAZOC4W',
#  'XPANTO4',
#  'XGNS150',
#  'INAH',
#  'XRAMOSET',
#  'TULOB.5-HW',
#  'LEVETI2',
#  'CARBO-TG',
#  'SOLIF5',
#  'APH325',
#  'GEMIG50',
#  'XEPHE',
#  'MIRABE5',
#  'XNSTIG',
#  'XMPD40',
#  'BESZYM',
#  'AMIT1',
#  'RFP3',
#  'ROP.25',
#  'PLKAST1W',
#  'CIL100SRC',
#  'XXHUMA3',
#  'PGCIN-S',
#  'HTZ',
#  'XICGR',
#  'OMEP40B',
#  'PGE1',
#  'CIPR2',
#  'TM-TO',
#  'RABEP10',
#  'PERIND',
#  'MUPIR1W-O',
#  'AMX5W',
#  'LCTZINPSU',
#  'COLCH',
#  'XHEPAR5',
#  'DDP2W',
#  'XHYOS',
#  'OSELTAM',
#  'GINCOSAN',
#  'UDCA2',
#  'XD5W100',
#  'NIFED40C',
#  'XGM80',
#  'OXCARB3',
#  'KREME-K',
#  'T4',
#  'SIT50M8',
#  'XNEFOP20',
#  'CELEB2W',
#  'HXZIN10W',
#  'PCYCL',
#  'LEVETI5',
#  'XVECUR10Y',
#  'MONTEL10W',
#  'ROSUV20W',
#  'DOXOFY',
#  'NB5',
#  'LITH',
#  'EMB',
#  'AZEL',
#  'XPROPO115W',
#  'CDTREN-W',
#  'ACYST-S',
#  'OFLO-E',
#  'RISP1',
#  'METR',
#  'EUPATIL',
#  'DVALP5ER',
#  'PIOGLI15',
#  'PRAV40',
#  'ISMN20',
#  'DULOX60',
#  'XXHUMA253',
#  'OSELTAM30',
#  'CLAR5',
#  'ALE70D53',
#  'XNICAR',
#  'AMPSUL',
#  'CILOS200',
#  'XPLASMA1W',
#  'XCPIRA',
#  'DORZOT-T',
#  'SIT50M10',
#  'GABAP3Y',
#  'VALSAR',
#  'XMETR500',
#  'DILT30',
#  'MEGES4-K10',
#  'NEBIV5',
#  'DAPAG10',
#  'LANSOP15',
#  'AMLODS2.5',
#  'SMEC-S',
#  'TIBOL2.5',
#  'ENTER150',
#  'CIN2DIM4',
#  'AM5TEL40',
#  'INDOM25',
#  'XFENT100',
#  'BLICHEN5',
#  'BRIM.1-T',
#  'CZPAM',
#  'MIRTA7',
#  'DIACER5W',
#  'PANTOP40',
#  'ALCAR500V',
#  'APH6TR7ER',
#  'LANSOPR15',
#  'CENTRUMA',
#  'XPTS500',
#  'PIREN-T',
#  'XFEN50',
#  'OLMET20',
#  'ALGIN-K',
#  'DILAT3',
#  'LINAGL2M5',
#  'RACEC1-K',
#  'MEGES4-K20',
#  'BZD.3-A',
#  'FEXO120',
#  'MPHEN10',
#  'ALCAFT-T',
#  'XBPCA.5H4',
#  'MTPROL',
#  'MONTEL4CH',
#  'MZ',
#  'MIRTZ15',
#  'XNS100P',
#  'TACRO.1-O',
#  'XCIPR4',
#  'XCIMETR',
#  'XOMAP72',
#  'ESCITA20',
#  'CLOPIB75',
#  'DOMPM',
#  'XPCMOL1P',
#  'VORTI5',
#  'ROSUV5Y',
#  'WARF2',
#  'TIROP',
#  'LDB250',
#  'GABAP3',
#  'DGX',
#  'XHEPAR1',
#  'MTX2.5',
#  'PINAV',
#  'DILAT25',
#  'CL75A100',
#  'LOSA100',
#  'CENTRUMSLA',
#  'SITAG100',
#  'BUPRO1W',
#  'RAN300',
#  'BZYD1-NB',
#  'SCZOL-CR',
#  'AZITH-S',
#  'XD5W5',
#  'XFEN500P',
#  'LDPIZ',
#  'PZA5',
#  'XCTXM2G',
#  'XPSTIG',
#  'XCZEDO2G',
#  'SERTR50',
#  'X10IFUS5',
#  'APIXA2',
#  'DDP5',
#  'XB12',
#  'TOB-T',
#  'KTOPEL-H',
#  'TELMIS80',
#  'CY-T',
#  'XFURO',
#  'LOFLO500',
#  'XNITR10',
#  'TICAG90',
#  'LCLOPE-P',
#  'FLF5120-N',
#  'XIGLY10',
#  'LSULPR',
#  'XESOME40',
#  'ISDN40',
#  'EZESIM10',
#  'ALPRA2W',
#  'PSTYR-K',
#  'T4150',
#  'V2F1-D',
#  'XB1',
#  'XPALON75',
#  'XMELPRO2',
#  'ALVESIM6W',
#  'PDF10-T',
#  'XD5S5',
#  'TIANEP',
#  'XAZITH',
#  'ROSUV10Y',
#  'XD5W',
#  'PGI2',
#  'LATAN-T',
#  'LINAGL2M8',
#  'CLOPID75Z',
#  'BIMAT.1-T',
#  'KPROF-GL',
#  'TIOTR5-Y',
#  'MONTEL5CH',
#  'B1F120-A',
#  'AMIOD',
#  'MELOX15W',
#  'CILN10',
#  'XBH',
#  'PSTYR5-KS',
#  'NIFEDO60',
#  'ATORV10W',
#  'LOCE5-NL',
#  'TZOS5',
#  'XXINFL5SH',
#  'TACRO-O',
#  'KCZOL-CR',
#  'BOS-L',
#  'LID700-H',
#  'VMED50',
#  'XCMN9GE1',
#  'GODEX',
#  'CILOS50',
#  'NAFR100X',
#  'CICLE5-NS',
#  'ROSUV20',
#  'LOPEROX',
#  'CH.1-GA',
#  'HCQ200',
#  'CAACET',
#  'XXIGLY4',
#  'PITAV2',
#  'PRAV20',
#  'BUPRE5-H',
#  'XPHEPH1',
#  'ES.05-GL',
#  'EZEROSU5',
#  'XGD5W2',
#  'XFAMO',
#  'METFOR5XRW',
#  'IRSOG4',
#  'CDP10',
#  'EMLA-CR',
#  'TNAF',
#  'OLMET40',
#  'IRB1ATO1',
#  'XEPIN',
#  'LDC125',
#  'TEPREN',
#  'TI5BR10-T',
#  'PSTYR5-K',
#  'VALAC5',
#  'METFOR2',
#  'XCMTAZ',
#  'OMEGA31W',
#  'GEMIG5M1',
#  'DIBUP-S',
#  'ROSUV5W',
#  'SALAZ',
#  'ZOLMIT',
#  'LOBEG',
#  'XVARIZO',
#  'SARPOG3',
#  'EZESIM20',
#  'XMORPS5',
#  'BISA-P',
#  'AM5LO50',
#  'CILN5',
#  'ESCIT10',
#  'FIMAS60',
#  'SUMAT',
#  'TRAMAPH3X',
#  'XKETA5',
#  'ARIPIP2',
#  'AZOS10XL1W',
#  'OSELTAM45',
#  'ALCA500-K',
#  'CALCIT.25',
#  'NIFEDO30',
#  'CHR-S',
#  'T450W',
#  'XLID2W',
#  'TRANEX',
#  'MIRTZ30',
#  'LOTEP-T',
#  'SIT50M5XR',
#  'FEN1-H',
#  'CANDES8',
#  'XD10W',
#  'ROXIT150',
#  'XPNEUM13A',
#  'LAMO25',
#  'DILAT16SR',
#  'GEMIG5M5',
#  'MOSAP5Y',
#  'EROTRI',
#  'AMX-S',
#  'TREST',
#  'XXEPOA10K',
#  'OLOP.2-T',
#  'OXCON5',
#  'ROSUV5',
#  'IBUP',
#  'SYLCON',
#  'AMLATO10',
#  'MESOG50',
#  'AMXCL3',
#  'CIPO25',
#  'AML50OL20',
#  'RIVAR15',
#  'RIVAR20',
#  'UREA-CR',
#  'BSSP-L',
#  'CRADIN5',
#  'XNITR10F',
#  'PIOGLI30',
#  'MOXIFL',
#  'AZOS10XL',
#  'TRIHE',
#  'XSMOFKP14',
#  'LOSA100W',
#  'FLUC',
#  'RWACHOL',
#  'ACYC-CR',
#  'XMCARBA5',
#  'XD10W5',
#  'XRPCA7',
#  'RASAG1',
#  'XXINFLT5',
#  'RISP2',
#  'POLMACO2',
#  'X6PAMI5',
#  'THGLC-CR',
#  'CLZA100',
#  'ESCITA15',
#  'AM5LO100',
#  'ISMN60',
#  'ATEN25',
#  'FOSFO-K',
#  'B1F60-TH',
#  'XDICLOF',
#  'TULOB2-H',
#  'VALSAR160',
#  'RALOX60',
#  'KALLID50W',
#  'DONEP23',
#  'FENOF135',
#  'XAMP5',
#  'XACYC',
#  'EZEATO20',
#  'AM5TEL80',
#  'MYP-T',
#  'BNCHOL25',
#  'CALFOS4Z',
#  'MELATO2',
#  'PPEX.5',
#  'SAXAG5M1',
#  'XMAROA22',
#  'ZOLP6CR',
#  'GO75-S',
#  'XXHUMA553',
#  'CMCYS2-S',
#  'ATEN50',
#  'XLZPAM2',
#  'CIPRHC-E',
#  'BUP10',
#  'SAXAG5',
#  'X10CAFS5',
#  'PANTO40W',
#  'IRBESA1',
#  'XAMPSUL15',
#  'CACA1D4',
#  'XCTOC100',
#  'XFOMSP9',
#  'VMED',
#  'VORTI10',
#  'CHOLA400',
#  'XXIPA73',
#  'LOSAHTZ',
#  'AMX2',
#  'AMLODCA',
#  'SIMVCR20',
#  'G2MET5',
#  'CANDES16',
#  'PDCARB-O',
#  'TNAF-CR',
#  'TENOF300W',
#  'TENELI20',
#  'B1F120-TH',
#  'FLEC',
#  'KTIFEN',
#  'X20M1X',
#  'TIMO-T',
#  'RISPE1H',
#  'HCQ100',
#  'TAFLUS15-T',
#  'XIBAND3',
#  'TEL4ROSU1',
#  'LOSA50W',
#  'X20AL1S',
#  'MEQUIT-S',
#  'XC500',
#  'XHD',
#  'MPD-LT',
#  'CTZIN',
#  'XCTRX',
#  'CXIM-W',
#  'XCAGL',
#  'BUPRE10-H',
#  'AMLODS5',
#  'XAMIOD',
#  'CLTHC1W-CR',
#  'HYOS',
#  'HCORT1-L',
#  'XSUGAM2',
#  'FENOF160M',
#  'WARF5',
#  'HURON18-T',
#  'SIMV20',
#  'PERIND8',
#  'AGIO-K',
#  'LINAGL2M10',
#  'XXEPOA4K',
#  'VOGLIB3',
#  'XIRONSU',
#  'VENL37P',
#  'ATORV10Z',
#  'PRAV10',
#  'XCLM',
#  'PHAZYM',
#  'XNORE10',
#  'XHS5',
#  'XCPZSUL',
#  'DOR2T5-S',
#  'FORMO1-S',
#  'EBAPSU',
#  'DNP-TO',
#  'HCOR10',
#  'CIME2',
#  'KCON6',
#  'XXEPOA6K',
#  'XVANCO1',
#  'CLOPIR75',
#  'ZONISA',
#  'XRANIB.5',
#  'BCOM',
#  'NAFTA',
#  'X10HEP5',
#  'XD50W1',
#  'OLOP.2W-T',
#  'TRAM100',
#  'XFOMSP14',
#  'AM10L50',
#  'XHNS',
#  'XACYST',
#  'KTIFEN-S',
#  'SPANTO10',
#  'BISAD',
#  'XOXYT',
#  'ARIPIP5',
#  'AMISUL1',
#  'PREPH-O',
#  'XIGLUL10',
#  'XCTIAM',
#  'OMEGA31',
#  'OMEP10',
#  'CPIR15W-SH',
#  'EZEROSU10',
#  'HARMO2W-B',
#  'XGOSE',
#  'MONTEL10X',
#  'SAXAG5M5',
#  'ISDN300-A',
#  'TRIFLU',
#  'AM5LO50W',
#  'IMIDA.1',
#  'ACECL1X',
#  'XCMINX',
#  'BEPOT9',
#  'THIOCT6X',
#  'B320F60-TH',
#  'OLAN2.5',
#  'MPD-CR',
#  'ALEND70',
#  'CUROX2Y',
#  'G1MET5',
#  'XCTRX5',
#  'LANSOP',
#  'FAMC7',
#  'IRB3ATO1',
#  'AJ',
#  'OLMET10',
#  'FINAS5',
#  'DILAT8SR',
#  'XXHINFB',
#  'GALTAS-W',
#  'AML5VA8',
#  'XXBEMI35',
#  'XXDTPP',
#  'UDCA3',
#  'DILAT32SR',
#  'XHURON75',
#  'SAL200-A',
#  'NACL-W',
#  'TANDOS5',
#  'X10PROA5',
#  'XPNEUMO13',
#  'GABAP6',
#  'VAREN.5',
#  'CUDCA250',
#  'AM2TEL40',
#  'DDS100',
#  'CANDES16W',
#  'RAN75',
#  'PANTO40',
#  'CUROX2X',
#  'RIVAS10-H',
#  'XXDARBE120',
#  'BSS-L',
#  'XXENOX40',
#  'NALTRE',
#  'PITAV2W',
#  'TULOB1-HW',
#  'PLK100-W',
#  'FL.55-T',
#  'VID50M1000',
#  'XXEPOA8K',
#  'XHEP100PM',
#  'OXYC10N5',
#  'XXIDET3',
#  'XLID2',
#  'TEL8HTZ',
#  'ACLID60-D',
#  'VALPR-S',
#  'XC10W',
#  'MOLSIDO4',
#  'IRONA-K',
#  'AML5VA16',
#  'LEVETI2Y',
#  'XPSPA',
#  'DABIG150',
#  'EZEATO10',
#  'THROM-W',
#  'ALPRA5',
#  'ROTARIX-S',
#  'RABEP10Y',
#  'BCG-H',
#  'XLEVET500',
#  'F2S5-AK',
#  'FIMAS120',
#  'HDR',
#  'OLM2ROSU1',
#  'VID50M850',
#  'DANTR25',
#  'AZAT50Y',
#  'PGCIND',
#  'XTRIPTO3',
#  'DABIG110',
#  'AML5OL40',
#  'APIXA5',
#  'XXIDEGL3',
#  'GEMIG2M5',
#  'XPROG',
#  'TAMSU.2D',
#  'LOFLO250',
#  'ATORV20Z',
#  'DFCORT1W-O',
#  'MYRT300',
#  'LAMO100',
#  'DXM',
#  'CXIM',
#  'FLUC-S',
#  'RACEC3-K',
#  'XXNPH3',
#  'LDB125D',
#  'DIENOG2',
#  'LEVETI1G',
#  'RASUBI1Y',
#  'XLOFLO5',
#  'OXYC5N2',
#  'XCALCIT1',
#  'AMX7CL',
#  'PVP-VS',
#  'ITCON',
#  'TRANIL',
#  'XHBV10',
#  'VALPR5',
#  'XHCS100',
#  'DONEP10C',
#  'ISMN40',
#  'EZEATO40',
#  'ETIZOL.5',
#  'CACB500',
#  'COTRIM',
#  'CAL1-L',
#  'TN-T',
#  'FOXET20D',
#  'PSTIG60',
#  'XAFLIB',
#  'SIM2FENOF',
#  'MPRG10',
#  'SILOD4W',
#  'MELOX7.5X',
#  'STILLX',
#  'X10PROA2',
#  'FEBUX40',
#  'PFENON2SR',
#  'CANDHTZ',
#  'OCTYL40',
#  'DOMP-S',
#  'TEL8ROSU1',
#  'PERAMP2',
#  'XNFMOS10',
#  'XHR10',
#  'CLM',
#  'IPRAT-N',
#  'AM5OL4HTZ',
#  'AVOCA300',
#  'LAMO50',
#  'EESTDROS',
#  'TOPIR25',
#  'SILDC100',
#  'TORAS5',
#  'ITOPRI5W',
#  'XHYALU15W',
#  'BRH',
#  'XXCTRX2',
#  'PAROXCR',
#  'OLM2ROSU5',
#  'MONTEL4-K',
#  'CILOS100S',
#  'SIT50M1XR',
#  'X2TAUR2',
#  'XHBV20',
#  'ACYST1',
#  'XBABA',
#  'XD20W20',
#  'XDOPA4D2',
#  'ILAPR10',
#  'MISOP2',
#  'LERCAN',
#  'XLABETA',
#  'RIVAS5-H',
#  'ZOLP12CR',
#  'YAL-L',
#  'PRAV40W',
#  'FIMA6HTZ',
#  'RETAP-O',
#  'XHPD',
#  'RAMIP2',
#  'COUGH-K',
#  'FEBUX80',
#  'NEBIV2',
#  'IRSOG2ODT',
#  'NS-L',
#  'RIFAX200',
#  'LEVE100-S',
#  'EZETIM',
#  'BROMF-T',
#  'MELOX15Y',
#  'AM10OL4HTZ',
#  'AM5OL2HTZ',
#  'OLAN5',
#  'BUSP5',
#  'ISDN120',
#  'PDCARB-L',
#  'AMX7CL5W',
#  'HARMO5W-B',
#  'XLHRH',
#  'NICER10',
#  'CELEB1W',
#  'XVANC1G',
#  'ENTEC.5',
#  'LORCAS',
#  'XMPD1',
#  'RFP1',
#  'OLM20HC12',
#  'ACYC',
#  'BRIMB-T',
#  'G2MET5EX',
#  'CLZA25',
#  'PSYL-K',
#  'ROP1',
#  'FESTOPR4',
#  'XK40',
#  'LNORG52',
#  'PDV-60L',
#  'CECLO-S',
#  'BUP',
#  'DZOS4XL',
#  'NEBIV5W',
#  'ESOMST40',
#  'XCISACUR',
#  'XXTDAP',
#  'CACI1D4',
#  'TADAL5W',
#  'TEL4HTZ',
#  'XNB84',
#  'MEGES10-K6',
#  'ONG-V',
#  'GINKB80W',
#  'HCQ15',
#  'VAREN1',
#  'METR-GL',
#  'XTNAPER9',
#  'TOSUFL',
#  'ZOLPID5',
#  'PANTO20',
#  'RAMIP5',
#  'MENI',
#  'AZAT50X',
#  ...]

# %%
categorical_columns = []
for feature, vocab in CATEGORIES.items():
    cat_col = tf.feature_column.categorical_column_with_vocabulary_list(key=feature, 
                                                                        vocabulary_list=vocab)
    categorical_columns.append(tf.feature_column.indicator_column(cat_col))

# %%
categorical_columns[0]
# Out:
# IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key=' order_date', vocabulary_list=('2016-12-19', '2016-12-12', '2016-12-05', '2016-11-28', '2016-12-14', '2016-11-30', '2016-12-13', '2016-12-21', '2016-12-15', '2016-12-16', '2016-12-26', '2016-12-20', '2016-11-14', '2016-12-23', '2016-12-22', '2016-11-07', '2016-12-02', '2016-11-21', '2016-12-01', '2016-11-01', '2016-11-29', '2016-11-02', '2016-12-27', '2016-11-16', '2016-12-07', '2016-12-28', '2016-11-23', '2016-12-09', '2016-12-06', '2016-11-22', '2016-12-30', '2016-11-15', '2016-11-24', '2016-12-08', '2016-11-08', '2016-11-18', '2016-11-11', '2016-11-09', '2016-11-17', '2016-12-29', '2016-11-10', '2016-11-25', '2016-11-03', '2016-11-04', '2016-12-03', '2016-12-10', '2016-12-17', '2016-12-24', '2016-11-12', '2016-11-05', '2016-11-19', '2016-11-26', '2016-12-31', '2016-12-18', '2016-12-25', '2016-12-11', '2016-12-04', '2016-11-13', '2016-11-27', '2016-11-06', '2016-11-20'), dtype=tf.string, default_value=-1, num_oov_buckets=0))

# %%
categorical_layer = tf.keras.layers.DenseFeatures(categorical_columns)

# %%
preprocessing_layer = tf.keras.layers.DenseFeatures(categorical_columns+numeric_columns)
